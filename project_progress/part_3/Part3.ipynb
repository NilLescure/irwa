# %%
# Imports
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
from collections import defaultdict
from array import array
import numpy as np
import math
import collections
from numpy import linalg as la
import re

# !pip3 install gensim
from gensim.models import Word2Vec

import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Load data
processed_df = pd.read_csv("/content/drive/Shareddrives/IRWA/P3/processed_df.csv")
clean_df = pd.read_csv("/content/drive/Shareddrives/IRWA/P3/clean_df.csv")

# %%
# Part1 function
def preproces_text(text):
    if not isinstance(text, str):
        return []

    stop_words = set(stopwords.words('english'))
    stemmer = PorterStemmer()
    text = text.lower()
    tokens = word_tokenize(text)
    tokens = [t for t in tokens if t.isalpha()]
    tokens = [t for t in tokens if t not in stop_words]
    tokens = [stemmer.stem(t) for t in tokens]

    return tokens

# %%
# Part 2 queries
queries = {
    1: "men cotton round neck clothes",
    2: "women and men neck accessories",
    3: "men casual black slim shirt",
    4: "women casual blue collar",
    5: "poor men biodegradable clothes"
}

# %% [markdown]
# Excercisi 1a)

# %%
# Indexing including doc_length and avg_doc_lenght
def create_index_tfidf_bm25(dataframe, clean_df, columns, num_documents):
    index = defaultdict(list)
    tf = defaultdict(list)
    df = defaultdict(int)
    title_index = defaultdict(str)
    idf = defaultdict(float)
    doc_lengths = {}
    total_length = 0

    for index_val, row in dataframe.iterrows():
        page_id = row['pid']
        terms = []
        for col in columns:
            val = row[col]
            trobat = re.findall(r"'([^']+)'", val)
            terms.extend(trobat)

        title = row['title']
        title = clean_df.loc[clean_df['pid'] == page_id, 'title'].values[0]
        title_index[page_id] = title

        current_page_index = {}

        for position, term in enumerate(terms):
            try:
                current_page_index[term][1].append(position)
            except:
                current_page_index[term] = [page_id, array('I', [position])]

        norm = 0
        for term, posting in current_page_index.items():
            norm += len(posting[1]) ** 2
        norm = math.sqrt(norm)

        doc_lengths[page_id] = len(terms)
        total_length += len(terms)

        for term, posting in current_page_index.items():
            tf[term].append(np.round(len(posting[1]) / norm, 4))
            df[term] += 1

        for term_page, posting_page in current_page_index.items():
            index[term_page].append(posting_page)

    for term in df:
        idf[term] = np.round(np.log(float(num_documents / df[term])), 4)

    avg_doc_length = total_length / num_documents

    return index, tf, df, idf, title_index, doc_lengths, avg_doc_length

# %%
# Create the index
indexing_columns = ['title', 'description', 'brand', 'category', 'sub_category', 'product_details', 'seller']
index, tf, df, idf, title_index, doc_lengths, avg_doc_length = create_index_tfidf_bm25(processed_df, clean_df, indexing_columns, len(processed_df))

# %%
# Ranking TF-IDF + cosine similarity
def rank_documents_tf_idf_cos(terms, docs, index, idf, tf):
    doc_vectors = defaultdict(lambda: [0] * len(terms))
    query_vector = [0] * len(terms)
    query_terms_count = collections.Counter(terms)
    query_norm = la.norm(list(query_terms_count.values()))

    for termIndex, term in enumerate(terms):
        if term not in index:
            continue
        query_vector[termIndex] = query_terms_count[term] / query_norm * idf[term]

        for doc_index, (doc, postings) in enumerate(index[term]):
            if doc in docs:
                doc_vectors[doc][termIndex] = tf[term][doc_index] * idf[term]

    query_vector = np.array(query_vector, dtype=float)
    query_norm = la.norm(query_vector)
    if query_norm == 0:
        return [], []

    doc_scores = []
    for doc, curDocVec in doc_vectors.items():
        curDocVec = np.array(curDocVec, dtype=float)
        doc_norm = la.norm(curDocVec)
        if doc_norm == 0:
            continue
        dot_score = float(np.dot(curDocVec, query_vector))
        cos_sim = float(dot_score / (doc_norm * query_norm))
        doc_scores.append([cos_sim, doc])

    doc_scores.sort(reverse=True)
    result_docs = [x[1] for x in doc_scores]
    if len(result_docs) == 0:
        print("No results found, try again")
        query = input()
        docs = search_tf_idf_cos(query, index)
    return result_docs, doc_scores

# %%
# Search with the TF-IDF + cosine similarity rank function
def search_tf_idf_cos(query, index, idf, tf):
    query = preproces_text(query)
    docs = None
    for term in query:
        try:
            term_docs = [posting[0] for posting in index[term]]

            if docs is None:
                docs = term_docs
            else:
                docs &= term_docs
        except:
            pass
    docs = list(docs)
    ranked_docs,doc_scores = rank_documents_tf_idf_cos(query, docs, index, idf, tf)
    return ranked_docs,doc_scores

# %%
# Print the top 20 of the Part2 queries(with TF-IDF + cosine similarity score)
top = 20
print("Our defined queries with the respective search (with TF-IDF + cosine similarity score):")
for query_id, query_text in queries.items():
    ranked_docs, scores = search_tf_idf_cos(query_text, index, idf, tf)
    print("\n======================")
    print(f"Top {top} results out of {len(ranked_docs)} for the query: {query_text}\n")
    for doc_id in ranked_docs[:top]:
        title = title_index[doc_id]
        print(f"Document: {doc_id} | Title: {title}")
# Out:
# Our defined queries with the respective search (with TF-IDF + cosine similarity score):
#
# ======================
# Top 20 results out of 14232 for the query: men cotton round neck clothes
#
# Document: SWSF7NWDK2FMWHVQ | Title: Full Sleeve Self Design Men Sweatshirt
# Document: TSHFGK39PUWYFPXB | Title: Printed Men Round Neck Maroon, Beige T-Shirt
# Document: TSHFGJXFD9ZPQPGD | Title: Printed Men Round Neck White, Maroon T-Shirt
# Document: TSHFGJX75VHXH2TP | Title: Color Block Men Round Neck White, Maroon T-Shirt
# Document: TSHFGJXFMGFC487C | Title: Printed Men Round Neck Maroon, Beige T-Shirt
# Document: TSHFGJX73DGYA27D | Title: Color Block Men Round Neck Black, Yellow T-Shirt
# Document: TSHFMGMYWTKUAGQB | Title: Printed Men Round Neck Black T-Shirt
# Document: TSHFHBSNXBHDF6AF | Title: Printed Men Round Neck Black T-Shirt
# Document: TSHFHBSNSXSMUDPH | Title: Printed Men Round Neck White T-Shirt
# Document: TSHFGZGBWSZXERPM | Title: Color Block Men Round Neck White T-Shirt
# Document: TSHFTW29PUDGZVBS | Title: Solid Men Round Neck Green T-Shirt  (Pack of 3)
# Document: TSHFTW29TJFZTYSQ | Title: Solid Men Round Neck Green T-Shirt  (Pack of 3)
# Document: TSHFTW29DEQTHXQN | Title: Solid Men Round Neck Green T-Shirt  (Pack of 3)
# Document: TSHFGZGBWW7NQMYT | Title: Color Block Men Round Neck Beige T-Shirt
# Document: TSHFQ3D3FHRXGRGZ | Title: Printed Men Round Neck Yellow T-Shirt
# Document: TSHFZPENTY9GZ5FY | Title: Printed Men Round Neck Orange, Dark Blue T-Shirt  (Pack of 2)
# Document: TSHFV2GFFGUH7DY4 | Title: Solid Men Round Neck Red, Blue T-Shirt  (Pack of 2)
# Document: TSHFV2GCG9JFW36H | Title: Solid Men Round Neck Yellow, Blue T-Shirt  (Pack of 2)
# Document: TSHFPG3YYKCP5CKN | Title: Printed Men Round Neck Blue T-Shirt
# Document: TSHFPG3Y62GCADGY | Title: Printed Men Round Neck White T-Shirt
#
# ======================
# Top 20 results out of 13813 for the query: women and men neck accessories
#
# Document: TSHFUXPWUR2ZTEE2 | Title: Color Block Men V Neck Dark Blue T-Shirt
# Document: SWSFY5ZHEJ2HYWDG | Title: Full Sleeve Printed Men Sweatshirt
# Document: SWSFPGEZTZGTNG7J | Title: Full Sleeve Printed Men Sweatshirt
# Document: SWSFPGEZGUT2S8EZ | Title: Full Sleeve Printed Men Sweatshirt
# Document: SWSFPGEZFHYWZEDR | Title: Full Sleeve Printed Men Sweatshirt
# Document: SWSFPGEZETE9UCZT | Title: Full Sleeve Printed Men Sweatshirt
# Document: SWSFVZRFVZ2SZ3HZ | Title: Full Sleeve Solid Men Sweatshirt
# Document: SWSFVZRFTM4P9XGF | Title: Full Sleeve Solid Men Sweatshirt
# Document: SWSFVZRFNFMYYRCK | Title: Full Sleeve Solid Men Sweatshirt
# Document: SWSFVZRFDEQAKUH2 | Title: Full Sleeve Solid Men Sweatshirt
# Document: SWSFVZRFCWPPZVGT | Title: Full Sleeve Solid Men Sweatshirt
# Document: SWSFUNF6ZCFUZKHR | Title: Full Sleeve Printed Men Sweatshirt
# Document: SWSFUNF6XHCGGVCU | Title: Full Sleeve Printed Men Sweatshirt
# Document: SWSFUNF6VFJBYZZC | Title: Full Sleeve Printed Men Sweatshirt
# Document: SWSFUNF6TYFXREER | Title: Full Sleeve Printed Men Sweatshirt
# Document: SWSFPGX2M7SXUMP7 | Title: Full Sleeve Solid Men Sweatshirt
# Document: TSHFYRAGNUCA4UFZ | Title: Color Block, Typography Men Asymmetric Black, Grey T-Shirt
# Document: TSHEV2NSZ8WHTPAZ | Title: Solid Men Round or Crew White T-Shirt
# Document: RNCFYMZ6AKKHRJC4 | Title: Solid Men Raincoat
# Document: RNCFGGTR5JWV8ES9 | Title: Solid Men Raincoat
#
# ======================
# Top 20 results out of 14232 for the query: men casual black slim shirt
#
# Document: SHTFCGQYXBGACWGF | Title: Men Slim Fit Solid Spread Collar Casual Shirt
# Document: VESFHJHPZJUBPS49 | Title: SayItLoud Men Vest
# Document: VESFHJHPGM4MJADF | Title: SayItLoud Men Vest
# Document: SWSFN2XZM5KFN6EG | Title: Full Sleeve Solid Men Sweatshirt
# Document: TSHFYWYPPJXNWGKG | Title: Printed Men Polo Neck Grey T-Shirt
# Document: SHTFH3ZCKYFU9R3M | Title: Men Slim Fit Striped Casual Shirt
# Document: SHTFU86TUMGHAESZ | Title: Men Slim Fit Solid Spread Collar Casual Shirt
# Document: TROFYFX6ZF5DUKGH | Title: Slim Fit Men Black Cotton Blend Trousers
# Document: SHTFVSY6TVXST3US | Title: Men Slim Fit Solid Spread Collar Casual Shirt
# Document: SHTFU73NJ6UDVKRS | Title: Men Slim Fit Solid Spread Collar Casual Shirt
# Document: SHTFZJFDWJ4GSPAG | Title: Men Slim Fit Striped Spread Collar Casual Shirt
# Document: SHTFZJF87BBRZPFF | Title: Men Slim Fit Checkered Spread Collar Casual Shirt
# Document: SHTFZJFFZU9GQEVH | Title: Men Slim Fit Checkered Spread Collar Casual Shirt
# Document: SHTFZJFCWKXHWZHA | Title: Men Slim Fit Checkered Spread Collar Casual Shirt
# Document: SHTFZJFC8GHYGHTA | Title: Men Slim Fit Checkered Spread Collar Casual Shirt
# Document: SHTFZJF72Y8JBVGZ | Title: Men Slim Fit Checkered Spread Collar Casual Shirt
# Document: SHTFZHVFY3YMGYYY | Title: Men Slim Fit Printed Spread Collar Casual Shirt
# Document: TSHFUDU2WE62YQ5Z | Title: Solid Men Round Neck Black T-Shirt
# Document: TSHFYTZ82BG6ZBS6 | Title: Solid Men V Neck Black T-Shirt
# Document: TSHEXH59ZCT5CGHF | Title: Solid Men Round Neck Maroon, Black T-Shirt
#
# ======================
# Top 20 results out of 13813 for the query: women casual blue collar
#
# Document: SHTFUBSQ5MD8UGVY | Title: Women Slim Fit Solid Casual Shirt
# Document: SHTFS2GMZ6T3MFU6 | Title: Women Slim Fit Solid Slim Collar Casual Shirt
# Document: SHTFS2GMGZHUE9FQ | Title: Women Slim Fit Printed Slim Collar Casual Shirt
# Document: SHTFCGQ4B46XEA5F | Title: Women Slim Fit Solid Spread Collar Casual Shirt
# Document: SHTFAHDZ7H9ZFYNZ | Title: Women Slim Fit Striped Spread Collar Casual Shirt
# Document: BZRFNMGB3BE6ZPBN | Title: Printed Single Breasted Formal Women Full Sleeve Blazer  (Black)
# Document: SWSFGRFGWRX8HZBQ | Title: Full Sleeve Solid Women Sweatshirt
# Document: SHTFVNARSYMBMGV8 | Title: Women Regular Fit Solid Casual Shirt
# Document: SHTFS2GMDNUA2AGG | Title: Women Slim Fit Printed Slim Collar Casual Shirt
# Document: SHTFS2GMBYSVTZME | Title: Women Slim Fit Solid Slim Collar Casual Shirt
# Document: SHTFCGQ46GFG4JPJ | Title: Women Slim Fit Solid Spread Collar Casual Shirt
# Document: SHTFCDSHVVMFGPE4 | Title: Women Slim Fit Solid Spread Collar Casual Shirt
# Document: SHTFUPWH7HFGUSNR | Title: Women Regular Fit Solid Button Down Collar Casual Shirt
# Document: SHTFUPWG2RWCGYZW | Title: Women Regular Fit Solid Button Down Collar Casual Shirt
# Document: SHTFVX89G2GXG96E | Title: Women Slim Fit Checkered Spread Collar Casual Shirt
# Document: SHTF98GZRZEXFJN3 | Title: Women Regular Fit Printed Button Down Collar Casual Shirt
# Document: SHTFJQFMYCKZKZHB | Title: Women Regular Fit Self Design Spread Collar Casual Shirt
# Document: SHTFHF5NHFYBYXJB | Title: Women Regular Fit Checkered Button Down Collar Casual Shirt
# Document: SHTFHF5MFFDTZPAB | Title: Women Regular Fit Self Design Button Down Collar Casual Shirt
# Document: SHTFEUYQJGHE9DKV | Title: Women Slim Fit Checkered Spread Collar Casual Shirt
#
# ======================
# Top 20 results out of 1 for the query: poor men biodegradable clothes
#
# Document: DHTFZGA8CNGYCUGT | Title: Vairavaa Tex 2.00'Meter(Single) | Kerala Traditional Mundu | 1'Inch Silver Border | 100% Cotton Solid Women Dhoti

# %% [markdown]
# Excercisi 1b)

# %%
# Ranking BM25
def rank_documents_bm25(terms, docs, index, idf, doc_length, avgdl, k1=1.2, b=0.75):
    N = len(doc_length)
    doc_scores = defaultdict(float)
    for termIndex, term in enumerate(terms):
        if term not in index:
            continue
        for doc_index, (doc, postings) in enumerate(index[term]):
            if doc in docs:
                tf_td = len(postings)
                Ld = doc_length[doc]
                denom = k1 * ((1 - b) + b * (Ld / avgdl)) + tf_td
                score = idf[term] * ((k1 + 1) * tf_td) / denom
                doc_scores[doc] += score

    doc_scores = [[score, doc] for doc, score in doc_scores.items()]
    doc_scores.sort(reverse=True)
    result_docs = [x[1] for x in doc_scores]
    if len(result_docs) == 0:
        print("No results found, try again")
        query = input()
        docs = search_bm25(query, index, idf, doc_length, avgdl)
    return result_docs, doc_scores

# %%
# Search with the BM25 rank function
def search_bm25(query, index, idf, doc_length, avgdl):
    query = preproces_text(query)
    docs = None
    for term in query:
        try:
            term_docs = [posting[0] for posting in index[term]]
            if docs is None:
                docs = term_docs
            else:
                docs &= term_docs
        except:
            pass
    docs = list(docs)
    ranked_docs,doc_scores = rank_documents_bm25(query, docs, index, idf, doc_length, avgdl)
    return ranked_docs,doc_scores

# %%
# Print the top 20 of the Part2 queries (with BM25 score)
top = 20
print("Our defined queries with the respective search (with TF-IDF + cosine similarity score):")
for query_id, query_text in queries.items():
    ranked_docs, scores = search_bm25(query_text, index, idf, doc_lengths, avg_doc_length)
    print("\n======================")
    print(f"Top {top} results out of {len(ranked_docs)} for the query: {query_text}\n")
    for doc_id in ranked_docs[:top]:
        title = title_index[doc_id]
        print(f"Document: {doc_id} | Title: {title}")
# Out:
# Our defined queries with the respective search (with TF-IDF + cosine similarity score):
#
# ======================
# Top 20 results out of 14232 for the query: men cotton round neck clothes
#
# Document: TSHFWF58KHZT8BBX | Title: Solid Men Round Neck Blue T-Shirt
# Document: TSHFWF57CHKBUNHE | Title: Solid Men Round Neck White T-Shirt
# Document: TSHFKQJRZXJ8ZHYB | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRJKFM6UGW | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRDDGJJGT4 | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRDA6FPV7B | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRBQQWXPTG | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKG8EMETSYN5E | Title: Striped Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRGXT5EV5G | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRGPZGYYDG | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRGBRAG59F | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJR59GQQVCK | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRTFCDQ2FB | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRT82DVT65 | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRQVJY8NUR | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRPNDCZCTH | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRFCGFGY3C | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRBKQEQTUF | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJR3QH3SR2D | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJQPHYJTYTG | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
#
# ======================
# Top 20 results out of 13813 for the query: women and men neck accessories
#
# Document: TSHFUXPWUR2ZTEE2 | Title: Color Block Men V Neck Dark Blue T-Shirt
# Document: TSHFXNQZTEHMG2AY | Title: Solid Men Round Neck Yellow T-Shirt
# Document: RNCF4YV4GZRYJY3A | Title: Solid Men Raincoat
# Document: RNCF4BYMQD53WHSF | Title: Solid Men Raincoat
# Document: TSHFN3ZNNGERFAFN | Title: Printed Men Round Neck Reversible White T-Shirt  (Pack of 2)
# Document: TSHFXYGDBYEPZRKX | Title: Solid Men V Neck Yellow T-Shirt
# Document: TSHFS2GDHHGKGBEV | Title: Printed Men Round Neck White T-Shirt
# Document: TSHFS2GDEWJZ6Q8S | Title: Printed Men Round Neck White T-Shirt
# Document: TSHFS2GCEHJGUHJT | Title: Printed Men Round Neck White T-Shirt
# Document: TSHFS2GCCJHJTKJ9 | Title: Printed Men Round Neck White T-Shirt
# Document: TSHFQ3E6KUMX2HHK | Title: Printed Men Round Neck White T-Shirt
# Document: TSHFXNQZQEJVT2ZA | Title: Solid Men Round Neck Maroon T-Shirt
# Document: TSHFXT7YNZNPW8BM | Title: Solid, Self Design Men Round Neck White T-Shirt
# Document: TSHFXT7F6HCBFBK3 | Title: Self Design, Solid Men Round Neck Maroon T-Shirt
# Document: TSHFXNRYBDB3QWZF | Title: Solid Men Round Neck White T-Shirt
# Document: TSHFS2GDKCMMYHY3 | Title: Printed Men Round Neck Yellow T-Shirt
# Document: TSHFS2GDGEUXWAYD | Title: Printed Men Round Neck White T-Shirt
# Document: TSHFS2GD4HHFXUCN | Title: Printed Men Round Neck White T-Shirt
# Document: TSHFUDQUTHREPSQ5 | Title: Printed Men Round Neck Multicolor T-Shirt
# Document: TSHFU7DHPE8TA9GQ | Title: Printed Men Round Neck Multicolor T-Shirt
#
# ======================
# Top 20 results out of 14232 for the query: men casual black slim shirt
#
# Document: SHTFZQJFGZYKGSNZ | Title: Men Slim Fit Printed Casual Shirt
# Document: SHTFS2GMYDEZKCXC | Title: Men Slim Fit Printed Slim Collar Casual Shirt
# Document: SHTFEBYZVY5XC6NM | Title: Men Slim Fit Solid Slim Collar Casual Shirt
# Document: SHTFEBYPJUXY6KHG | Title: Men Slim Fit Solid Slim Collar Casual Shirt
# Document: SHTFVY25HCH7WKG7 | Title: Men Slim Fit Printed Cut Away Collar Casual Shirt
# Document: SHTFXV5F797WT58R | Title: Men Slim Fit Printed Cut Away Collar Casual Shirt
# Document: SHTFXV5EFEBCMNUK | Title: Men Slim Fit Solid Cut Away Collar Casual Shirt
# Document: SHTFV5GYTWZZYXWH | Title: Men Slim Fit Checkered Cut Away Collar Casual Shirt
# Document: SHTEZY4NADWDYS9H | Title: Men Slim Fit Solid Spread Collar Casual Shirt
# Document: SHTFACSAS6WTFZ5G | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFRTGJHVMUVCZV | Title: Men Slim Fit Checkered Casual Shirt
# Document: SHTFH3ZCKYFU9R3M | Title: Men Slim Fit Striped Casual Shirt
# Document: SHTFS2GMGEMG2MUC | Title: Men Slim Fit Printed Slim Collar Casual Shirt
# Document: SHTFWD49HC2CFE5G | Title: Men Slim Fit Printed Slim Collar Casual Shirt
# Document: SHTEPHDP2VNTPEGR | Title: Men Slim Fit Solid Casual Shirt
# Document: SHTFSHYTFEUQPSKT | Title: Men Slim Fit Printed Spread Collar Casual Shirt
# Document: SHTF4EHG2KU74RX5 | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFMKQN4TUSUF7Z | Title: Men Slim Fit Solid Casual Shirt
# Document: SHTFEBYZYUZFGYYY | Title: Men Slim Fit Solid Spread Collar Casual Shirt
# Document: SHTFEBYZNPGT2QDG | Title: Men Slim Fit Solid Spread Collar Casual Shirt
#
# ======================
# Top 20 results out of 13813 for the query: women casual blue collar
#
# Document: SHTFHFU6RVB9WHQQ | Title: Women Slim Fit Solid Ruffle Collar Collar Casual Shirt
# Document: SHTF98GZRZEXFJN3 | Title: Women Regular Fit Printed Button Down Collar Casual Shirt
# Document: SHTFCBH4GE2GEMJG | Title: Women Slim Fit Solid Spread Collar Casual Shirt
# Document: SHTFHF5NHFYBYXJB | Title: Women Regular Fit Checkered Button Down Collar Casual Shirt
# Document: SHTFAHDZ7H9ZFYNZ | Title: Women Slim Fit Striped Spread Collar Casual Shirt
# Document: SHTFVNFNRRCU6GUH | Title: Women Slim Fit Checkered Spread Collar Casual Shirt
# Document: SHTF9FYP9ZHZHX4H | Title: Women Slim Fit Solid Spread Collar Casual Shirt
# Document: SHTFZHY7J7R56N3C | Title: Women Slim Fit Solid Curved Collar Collar Casual Shirt
# Document: TSHFHTGGGNAYNTGM | Title: Self Design Women Polo Neck Light Blue T-Shirt
# Document: SHTFJQFMYCKZKZHB | Title: Women Regular Fit Self Design Spread Collar Casual Shirt
# Document: SHTFS2GMBYSVTZME | Title: Women Slim Fit Solid Slim Collar Casual Shirt
# Document: SHTFQEDFHNKANNXZ | Title: Women Slim Fit Checkered Spread Collar Casual Shirt
# Document: SHTFHF5NH75NHHX9 | Title: Women Slim Fit Printed Button Down Collar Casual Shirt
# Document: SHTFS2GMDNUA2AGG | Title: Women Slim Fit Printed Slim Collar Casual Shirt
# Document: SHTF63EYQPGHCYEH | Title: Women Regular Fit Printed Curved Collar Collar Casual Shirt
# Document: SHTFS2GMZ6T3MFU6 | Title: Women Slim Fit Solid Slim Collar Casual Shirt
# Document: SHTFS2GMGZHUE9FQ | Title: Women Slim Fit Printed Slim Collar Casual Shirt
# Document: SHTFHF5MFFDTZPAB | Title: Women Regular Fit Self Design Button Down Collar Casual Shirt
# Document: SHTFZKXC2QSQMGHG | Title: Women Slim Fit Solid Curved Collar Collar Casual Shirt
# Document: SHTFZKYGZGEWTBPX | Title: Women Slim Fit Solid Curved Collar Collar Casual Shirt
#
# ======================
# Top 20 results out of 1 for the query: poor men biodegradable clothes
#
# Document: DHTFZGA8CNGYCUGT | Title: Vairavaa Tex 2.00'Meter(Single) | Kerala Traditional Mundu | 1'Inch Silver Border | 100% Cotton Solid Women Dhoti

# %% [markdown]
# Exercici 1 c)

# %%
# Versió fumada no fara falta
def create_index(df):
    """
    Crea un reverse index amb format:
    token → [ [pid, [field, [positions]], [field, [positions]], ...], ... ]
    """
    index = defaultdict(list)
    text_fields = ["title", "description", "brand", "category", "sub_category", "product_details", "seller"]

    for _, row in df.iterrows():
        pid = row["pid"]

        # index temporal per aquest document
        current_doc_index = defaultdict(lambda: defaultdict(lambda: array('I')))

        for field in text_fields:
            field_value = row[field]

            terms = [] # tokens

            for pos, term in enumerate(terms):
                current_doc_index[term][field].append(pos)

        # Afegim les dades del document a l’índex global
        for term, field_positions in current_doc_index.items():
            entry = [pid] + [[field, positions] for field, positions in field_positions.items()]
            index[term].append(entry)

    return index

# %%
# Reverse index for fields
def create_fields_index(dataframe, columns):
    index = defaultdict(list)
    for _, row in dataframe.iterrows():
        page_id = row['pid']
        term_fields = defaultdict(set)
        for col in columns:
            val = row[col]
            terms = re.findall(r"'([^']+)'", val)
            for term in terms:
                term_fields[term].add(col)

        for term, fields in term_fields.items():
            index[term].append([page_id, list(fields)])
    return index

# %%
# Create the field reverse index
indexing_columns = ['title', 'description', 'brand', 'category', 'sub_category', 'product_details', 'seller']
field_index = create_fields_index(processed_df, indexing_columns)

# %%
# Field weights
field_weights = {
    "title": 0.9,
    "brand": 0.25,
    "category": 0.25,
    "sub_category": 0.125,
    "description": 0.125,
    "product_details": 0.25,
    "seller": 0.1
}

# %%
# Ranking our socre
def rank_documents_ours(terms, docs, index, field_index, idf, doc_length, avgdl, k1=1.2, b=0.75):
    N = len(doc_length)
    doc_scores = defaultdict(float)
    for termIndex, term in enumerate(terms):
        if term not in index:
            continue
        term_field_map = {}
        if field_index is not None and term in field_index:
            for pid, fields in field_index[term]:
                term_field_map[pid] = fields

        for doc_index, (doc, postings) in enumerate(index[term]):
            if doc in docs:
                tf_td = len(postings)
                Ld = doc_length[doc]
                denom = k1 * ((1 - b) + b * (Ld / avgdl)) + tf_td
                score = idf[term] * ((k1 + 1) * tf_td) / denom

                fields = term_field_map.get(doc, [])
                if fields:
                    field_coeff = sum(field_weights.get(f, 0.0) for f in fields)
                else:
                    field_coeff = 0.0
                score = score * field_coeff

                doc_scores[doc] += score

    doc_scores = [[score, doc] for doc, score in doc_scores.items()]
    doc_scores.sort(reverse=True)
    result_docs = [x[1] for x in doc_scores]
    if len(result_docs) == 0:
        print("No results found, try again")
        query = input()
        docs = search_ours(query, index, field_index, idf, doc_length, avgdl)
    return result_docs, doc_scores

# %%
# Search with our rank function
def search_ours(query, index, field_index, idf, doc_length, avgdl):
    query = preproces_text(query)
    docs = None
    for term in query:
        try:
            term_docs = [posting[0] for posting in index[term]]
            if docs is None:
                docs = term_docs
            else:
                docs &= term_docs
        except:
            pass
    docs = list(docs)
    ranked_docs,doc_scores = rank_documents_ours(query, docs, index, field_index, idf, doc_length, avgdl)
    return ranked_docs,doc_scores

# %%
# Print the top 20 of the Part2 queries (with our score)
top = 20
print("Our defined queries with the respective search (with our score):")
for query_id, query_text in queries.items():
    ranked_docs, scores = search_ours(query_text, index, field_index, idf, doc_lengths, avg_doc_length)
    print("\n======================")
    print(f"Top {top} results out of {len(ranked_docs)} for the query: {query_text}\n")
    for doc_id in ranked_docs[:top]:
        title = title_index[doc_id]
        print(f"Document: {doc_id} | Title: {title}")
# Out:
# Our defined queries with the respective search (with our score):
#
# ======================
# Top 20 results out of 14232 for the query: men cotton round neck clothes
#
# Document: TSHFWF58KHZT8BBX | Title: Solid Men Round Neck Blue T-Shirt
# Document: TSHFWF57CHKBUNHE | Title: Solid Men Round Neck White T-Shirt
# Document: TSHFKQJRZXJ8ZHYB | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRJKFM6UGW | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRDDGJJGT4 | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRDA6FPV7B | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRBQQWXPTG | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKG8EMETSYN5E | Title: Striped Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRGXT5EV5G | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRGPZGYYDG | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRGBRAG59F | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJR59GQQVCK | Title: Printed Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRTFCDQ2FB | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRT82DVT65 | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRQVJY8NUR | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRPNDCZCTH | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRFCGFGY3C | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRBKQEQTUF | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJR3QH3SR2D | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJQPHYJTYTG | Title: Color Block Men Round Neck Multicolor T-Shirt  (Pack of 2)
#
# ======================
# Top 20 results out of 13813 for the query: women and men neck accessories
#
# Document: TSHFWF57CTFWRGFZ | Title: Solid Women Round Neck Black T-Shirt
# Document: TSHFKQJRZWJ5HCHF | Title: Printed Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRUVQC9N9H | Title: Printed Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRQSEQEJYG | Title: Printed Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRNZFJKB93 | Title: Printed Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRNCHQF9Y9 | Title: Printed Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRGMDTZAU6 | Title: Printed Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRA9TXD2NH | Title: Printed Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJR6FBHZYH2 | Title: Printed Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJR4JRSSM4W | Title: Printed Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKG8EGGRD6WGB | Title: Striped Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFTC58EYURFZMG | Title: Solid Women Round Neck Multicolor T-Shirt  (Pack of 4)
# Document: TSHFKQJRYEUUP5HN | Title: Color Block Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRSZQZRSZA | Title: Color Block Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRNU2HJRHZ | Title: Color Block Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRMFCPGCSH | Title: Color Block Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRHJPEDQZV | Title: Color Block Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRGBNPYYYQ | Title: Color Block Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRGA2VWTNN | Title: Color Block Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Document: TSHFKQJRFGH2PVX4 | Title: Color Block Women Round Neck Multicolor T-Shirt  (Pack of 2)
#
# ======================
# Top 20 results out of 14232 for the query: men casual black slim shirt
#
# Document: SHTFCQB3XRNSFCZD | Title: Men Slim Fit Checkered Spread Collar Casual Shirt
# Document: SHTFCQB3VPGKCJCG | Title: Men Slim Fit Checkered Spread Collar Casual Shirt
# Document: SHTFCQB39KUFUHEN | Title: Men Slim Fit Checkered Spread Collar Casual Shirt
# Document: SHTFACSAS6WTFZ5G | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTEZY4NADWDYS9H | Title: Men Slim Fit Solid Spread Collar Casual Shirt
# Document: SHTFZQJFGZYKGSNZ | Title: Men Slim Fit Printed Casual Shirt
# Document: SHTF4EHG2KU74RX5 | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFS2GMYDEZKCXC | Title: Men Slim Fit Printed Slim Collar Casual Shirt
# Document: SHTFACSAYCSXZKDA | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAUKWYMJYP | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSABCZFFTVE | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFEBYZVY5XC6NM | Title: Men Slim Fit Solid Slim Collar Casual Shirt
# Document: SHTFEBYPJUXY6KHG | Title: Men Slim Fit Solid Slim Collar Casual Shirt
# Document: SHTF4EHGZM3YK4R5 | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTF4EHGU2ZMCY3J | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTF4EHGT7Y87GS4 | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTF4EHGCKNVVYUB | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFEBYPPJQ5SN48 | Title: Men Slim Fit Checkered Casual Shirt
# Document: SHTF4EHGHJCGXDKS | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTF4EHG2PHCGQ5N | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
#
# ======================
# Top 20 results out of 13813 for the query: women casual blue collar
#
# Document: TSHFVK5RUZPUNQ3Q | Title: Solid Women Collared Neck Blue T-Shirt
# Document: TSHFVJ4462GRSQHZ | Title: Striped Women Collared Neck Blue T-Shirt
# Document: SHTFACSAZR3TNKKE | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAHWAJKSF3 | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAQFB6TPYF | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: TSHFXZSHYWFBU2HM | Title: Solid Women Collared Neck Dark Blue, Maroon T-Shirt  (Pack of 2)
# Document: TSHFXZSHHJWFGWNU | Title: Solid Women Collared Neck Dark Blue, Yellow T-Shirt  (Pack of 2)
# Document: TSHFVT954VKUYGFY | Title: Solid Women Collared Neck Blue T-Shirt
# Document: SHTFZZKCZWTVNNCY | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFZZKCHQKWRPEB | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: TSHFTXRFGE7HU2VH | Title: Printed Women Collared Neck Blue T-Shirt
# Document: SHTFACSAYNHFFRYF | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAYGXXZY3R | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAVUYVYDZX | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSASQVFFG3N | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSASKATTSTH | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAFFNPK4R5 | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTF4EHGWGCXGB3G | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTF4EHGW2UKUVFB | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTF4EHGBZGGHACP | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
#
# ======================
# Top 20 results out of 1 for the query: poor men biodegradable clothes
#
# Document: DHTFZGA8CNGYCUGT | Title: Vairavaa Tex 2.00'Meter(Single) | Kerala Traditional Mundu | 1'Inch Silver Border | 100% Cotton Solid Women Dhoti

# %% [markdown]
# Exercici 2

# %%
#create word2Vec model
indexing_columns = ['title', 'description', 'brand', 'category', 'sub_category', 'product_details', 'seller']
sentences = []
for index_val, row in processed_df.iterrows():
    page_id = row['pid']
    terms = []
    for col in indexing_columns:
        val = row[col]
        trobat = re.findall(r"'([^']+)'", val)
        terms.extend(trobat)
    if len(terms) > 0:
        sentences.append(terms)

w2v_model = Word2Vec(sentences=sentences, vector_size=100, window=10, min_count=10, negative=15, sg=0)

# %%
# doc_vector dictionary
docs_vectors = {}
dim = w2v_model.vector_size
for index_val, row in processed_df.iterrows():
    pid = row['pid']
    terms = []
    for col in indexing_columns:
        val = row[col]
        trobat = re.findall(r"'([^']+)'", val)
        terms.extend(trobat)

    word_vecs = []
    for t in terms:
        if t in w2v_model.wv:
            word_vecs.append(w2v_model.wv[t])

    if word_vecs:
        doc_vec = np.mean(word_vecs, axis=0)
    else:
        doc_vec = np.zeros(dim)

    docs_vectors[pid] = doc_vec

# %%
# Ranking word2vec score
def rank_documents_word2vec_cos(terms, docs, index, docs_vectors, w2v_model):
    query_w2v_embs = []
    for t in terms:
        if t in w2v_model.wv:
            query_w2v_embs.append(w2v_model.wv[t])

    if len(query_w2v_embs) > 0:
        query_w2v_vec = np.mean(query_w2v_embs, axis=0)
        query_w2v_norm = la.norm(query_w2v_vec)
        dim = query_w2v_vec.shape[0]
        doc_w2v_vectors = defaultdict(lambda: np.zeros(dim, dtype=float))
    else:
        query_w2v_vec = None
        query_w2v_norm = 0.0

    if query_w2v_norm == 0:
        print("No results found, try again")
        query = input()
        docs = search_word2vec_cos(query, index, docs_vectors, w2v_model)

    doc_scores = []
    for doc, curDocVec in docs_vectors.items():
        if doc in docs:
            curDocVec = np.array(curDocVec, dtype=float)
            doc_norm = la.norm(curDocVec)
            if doc_norm == 0:
                continue
            dot_score = float(np.dot(curDocVec, query_w2v_vec))
            cos_sim = float(dot_score / (doc_norm * query_w2v_norm))
            doc_scores.append([cos_sim, doc])

    doc_scores.sort(reverse=True)
    result_docs = [x[1] for x in doc_scores]
    if len(result_docs) == 0:
        print("No results found, try again")
        query = input()
        docs = search_word2vec_cos(query, index, docs_vectors, w2v_model)
    return result_docs, doc_scores

# %%
# Search with the word2vec rank function
def search_word2vec_cos(query, index, docs_vectors, w2v_model):
    query = preproces_text(query)
    docs = None
    for term in query:
        try:
            term_docs = [posting[0] for posting in index[term]]
            if docs is None:
                docs = term_docs
            else:
                docs &= term_docs
        except:
            pass
    docs = list(docs)
    ranked_docs,doc_scores = rank_documents_word2vec_cos(query, docs, index, docs_vectors, w2v_model)
    return ranked_docs,doc_scores

# %%
# Print the top 20 of the Part2 queries (with xord2vec + cosine score)
top = 20
print("Our defined queries with the respective search (with word2vec + cosine score):")
for query_id, query_text in queries.items():
    ranked_docs, scores = search_word2vec_cos(query_text, index, docs_vectors, w2v_model)
    print("\n======================")
    print(f"Top {top} results out of {len(ranked_docs)} for the query: {query_text}\n")
    for doc_id in ranked_docs[:top]:
        title = title_index[doc_id]
        print(f"Document: {doc_id} | Title: {title}")
# Out:
# Our defined queries with the respective search (with word2vec + cosine score):
#
# ======================
# Top 20 results out of 14232 for the query: men cotton round neck clothes
#
# Document: TSHFHUSFGYYARGZJ | Title: Self Design Men Round Neck Grey T-Shirt
# Document: TSHFWBWEZHVQEHYZ | Title: Solid Men Round Neck Grey T-Shirt  (Pack of 3)
# Document: TSHFWAWKUBZ9DQMX | Title: Solid Men Round Neck Light Blue T-Shirt  (Pack of 5)
# Document: TSHFWBWESMCTBUKC | Title: Solid Men Round Neck Dark Blue T-Shirt  (Pack of 3)
# Document: TSHFWAWKZ89QFZSQ | Title: Solid Men Round Neck Multicolor T-Shirt  (Pack of 5)
# Document: TSHFWAWKHA7VEBDW | Title: Solid Men Round Neck Black T-Shirt  (Pack of 5)
# Document: TSHFWBWEDVTTGYFG | Title: Solid Men Round Neck Multicolor T-Shirt  (Pack of 3)
# Document: TSHFWAWKG67G9FUX | Title: Solid Men Round Neck Grey T-Shirt  (Pack of 5)
# Document: TSHFW6HDXGGNXSYG | Title: Solid Men Round Neck Grey T-Shirt
# Document: TSHFWBWEGVAUJZMK | Title: Solid Men Round Neck Light Blue T-Shirt  (Pack of 3)
# Document: TSHFWAWKRWEDMYJ8 | Title: Solid Men Round Neck White T-Shirt  (Pack of 5)
# Document: TSHFWYW6RX8HP9YN | Title: Solid Men Round Neck Maroon T-Shirt
# Document: TSHFWBWEQMAJDPAT | Title: Solid Men Round Neck White T-Shirt  (Pack of 3)
# Document: TSHFHUSBHQKAFGTP | Title: Solid Men Round Neck Black T-Shirt
# Document: TSHFQ3D3SR4C3BCJ | Title: Printed Men Round Neck Brown T-Shirt
# Document: VESFVYNGFNRAUPU8 | Title: VIP Men Vest  (Pack of 3)
# Document: VESFVYNHAZKXRHK3 | Title: VIP Men Vest  (Pack of 9)
# Document: TSHFQ3D3DZUJNYGD | Title: Printed Men Round Neck Multicolor T-Shirt
# Document: TSHFYGTGVKW9GPFH | Title: Printed Men Round Neck White T-Shirt
# Document: TSHFHCWBZ2WRFADH | Title: Printed Men Round Neck Black T-Shirt
#
# ======================
# Top 20 results out of 13813 for the query: women and men neck accessories
#
# Document: TSHFGZP2UMURJVDW | Title: Abstract Women Round Neck Brown T-Shirt
# Document: TSHFGZP22PHZMR2Z | Title: Abstract Women Round Neck Brown T-Shirt
# Document: TSHFGJB5NZKTEU4H | Title: Abstract Women Round Neck Maroon T-Shirt
# Document: TSHFGJB5MMMQHGMU | Title: Abstract Women Round Neck Maroon T-Shirt
# Document: TSHFXU6XVVNRW2AZ | Title: Self Design, Solid Women Round Neck Yellow T-Shirt
# Document: TSHFGZP28Z6YUHQ8 | Title: Abstract Women Round Neck Green T-Shirt
# Document: TSHFGZP28GVBGSMG | Title: Abstract Women Round Neck Black T-Shirt
# Document: TSHFXYERRWUGYDZG | Title: Solid Women Round Neck Red T-Shirt
# Document: TSHEV2NRCXCMVXKZ | Title: Solid Women Round or Crew Beige T-Shirt
# Document: TSHFGJBYXHYNPYRP | Title: Self Design Women Round Neck Grey T-Shirt
# Document: TSHFGZP2PPMHHEDJ | Title: Abstract Women Round Neck Blue T-Shirt
# Document: TSHFGZP2NMGJ5PG8 | Title: Abstract Women Round Neck Blue T-Shirt
# Document: TSHFGJB5VTCBZXJD | Title: Abstract Women Round Neck Blue T-Shirt
# Document: TSHFGZP2Q8ZTZCGN | Title: Abstract Women Round Neck Brown T-Shirt
# Document: PLOFJQJD8WJBCADX | Title: AXMANN Round Neck Checkered Women Pullover
# Document: TSHEV2NRDJD4GQUD | Title: Solid Women Round or Crew Grey T-Shirt
# Document: PLOFJQJFTRHGHBXJ | Title: AXMANN Turtle Neck Striped Women Pullover
# Document: TSHFGJB5QYGBQ8FA | Title: Abstract Women Round Neck Maroon T-Shirt
# Document: TSHFXU6XAZHGYWD2 | Title: Solid, Self Design Women Round Neck White T-Shirt
# Document: TSHFWYW68HXUBHZS | Title: Solid Women Round Neck Dark Blue T-Shirt
#
# ======================
# Top 20 results out of 14232 for the query: men casual black slim shirt
#
# Document: SHTF4EHGZUJHPB7C | Title: Women Slim Fit Solid Casual Shirt
# Document: SHTFACSABCZFFTVE | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAS6WTFZ5G | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAQFB6TPYF | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAUKWYMJYP | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTF4EHGHJCGXDKS | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAVUYVYDZX | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAYCSXZKDA | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTF4EHG2PHCGQ5N | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTF4EHG2KU74RX5 | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAYGXXZY3R | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAZR3TNKKE | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAHWAJKSF3 | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAFFNPK4R5 | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTF4EHGCKNVVYUB | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTF4EHGU2ZMCY3J | Title: Men Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSAYNHFFRYF | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTFACSASKATTSTH | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTF4EHGWGCXGB3G | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
# Document: SHTF4EHGW2UKUVFB | Title: Women Slim Fit Solid Mandarin Collar Casual Shirt
#
# ======================
# Top 20 results out of 13813 for the query: women casual blue collar
#
# Document: SHTFVX89G2GXG96E | Title: Women Slim Fit Checkered Spread Collar Casual Shirt
# Document: SHTFCQ3CYDCGQGPZ | Title: Women Slim Fit Checkered Spread Collar Casual Shirt
# Document: SHTEJKHUZYY6HYHB | Title: Women Regular Fit Solid Spread Collar Collar Formal Shirt
# Document: SHTFZ6FV3RZA2PHE | Title: Women Regular Fit Solid Slim Collar Casual Shirt
# Document: SHTEZY7AQGCZGQ5H | Title: Women Slim Fit Solid Ribbed Collar Collar Casual Shirt
# Document: SHTFQEDFHNKANNXZ | Title: Women Slim Fit Checkered Spread Collar Casual Shirt
# Document: SHTFZ6FVQBZGZQ9V | Title: Women Regular Fit Solid Slim Collar Casual Shirt
# Document: SHTFZ746HNHYP6TH | Title: Women Regular Fit Solid Slim Collar Casual Shirt
# Document: SHTFZ746DXDHGY3W | Title: Women Regular Fit Solid Slim Collar Casual Shirt
# Document: SHTFZ6FVFV98HBYE | Title: Women Regular Fit Solid Slim Collar Casual Shirt
# Document: SHTFVNFNRRCU6GUH | Title: Women Slim Fit Checkered Spread Collar Casual Shirt
# Document: SHTFCVN3UKEVCMJS | Title: Women Slim Fit Solid Spread Collar Casual Shirt
# Document: SHTFZ6FVPYGPYHZY | Title: Women Regular Fit Solid Slim Collar Casual Shirt
# Document: SHTFV9X3CRSZSY9H | Title: Women Regular Fit Solid Slim Collar Casual Shirt
# Document: SHTFZ746NKBCMWE6 | Title: Women Regular Fit Solid Slim Collar Casual Shirt
# Document: SHTFZ746HVJBFCGM | Title: Women Regular Fit Solid Slim Collar Casual Shirt
# Document: SHTEJKHTMDJ68QFK | Title: Women Regular Fit Solid Spread Collar Collar Formal Shirt
# Document: SHTFVE66NTJM7MCU | Title: Women Regular Fit Solid Slim Collar Casual Shirt
# Document: SHTFWREF4BF9SGXD | Title: Women Regular Fit Solid Spread Collar Casual Shirt
# Document: SHTFZ746AKFPZ7MG | Title: Women Regular Fit Solid Slim Collar Casual Shirt
#
# ======================
# Top 20 results out of 1 for the query: poor men biodegradable clothes
#
# Document: DHTFZGA8CNGYCUGT | Title: Vairavaa Tex 2.00'Meter(Single) | Kerala Traditional Mundu | 1'Inch Silver Border | 100% Cotton Solid Women Dhoti
